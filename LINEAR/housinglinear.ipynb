# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import pickle

# %%
file=pd.read_csv("housing.csv",header=None)

# %%
df=pd.DataFrame(file)
df
# Out:
#                        0                    1                          2  \
# 0       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms
# 1      79545.45857431678    5.682861321615587          7.009188142792237
# 2      79248.64245482568   6.0028998082752425          6.730821019094919
# 3     61287.067178656784    5.865889840310001          8.512727430375099
# 4      63345.24004622798   7.1882360945186425          5.586728664827653
# ...                  ...                  ...                        ...
# 4996  60567.944139865984    7.830362443635721           6.13735622764076
# 4997   78491.27543459789    6.999134987291412          6.576762660738709
# 4998   63390.68688550463    7.250590614779546          4.805080980291155
# 4999   68001.33123508695    5.534388416220344          7.130143864349472
# 5000  65510.581803666224    5.992305307333977          6.792336104424982
#
#                                  3                   4                   5  \
# ...

# %%
column_name=['Income','House age','Number of rooms','Number of bedrooms','Population','Price','Address']

# %%
df.columns=column_name
df
# Out:
#                   Income            House age            Number of rooms  \
# 0       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms
# 1      79545.45857431678    5.682861321615587          7.009188142792237
# 2      79248.64245482568   6.0028998082752425          6.730821019094919
# 3     61287.067178656784    5.865889840310001          8.512727430375099
# 4      63345.24004622798   7.1882360945186425          5.586728664827653
# ...                  ...                  ...                        ...
# 4996  60567.944139865984    7.830362443635721           6.13735622764076
# 4997   78491.27543459789    6.999134987291412          6.576762660738709
# 4998   63390.68688550463    7.250590614779546          4.805080980291155
# 4999   68001.33123508695    5.534388416220344          7.130143864349472
# 5000  65510.581803666224    5.992305307333977          6.792336104424982
#
#                 Number of bedrooms          Population               Price  \
# ...

# %%
encode=LabelEncoder()

# %%
df['Address']=encode.fit_transform(df['Address'])
df
# Out:
#                   Income            House age            Number of rooms  \
# 0       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms
# 1      79545.45857431678    5.682861321615587          7.009188142792237
# 2      79248.64245482568   6.0028998082752425          6.730821019094919
# 3     61287.067178656784    5.865889840310001          8.512727430375099
# 4      63345.24004622798   7.1882360945186425          5.586728664827653
# ...                  ...                  ...                        ...
# 4996  60567.944139865984    7.830362443635721           6.13735622764076
# 4997   78491.27543459789    6.999134987291412          6.576762660738709
# 4998   63390.68688550463    7.250590614779546          4.805080980291155
# 4999   68001.33123508695    5.534388416220344          7.130143864349472
# 5000  65510.581803666224    5.992305307333977          6.792336104424982
#
#                 Number of bedrooms          Population               Price  \
# ...

# %%
'''df['Price'].replace('?',np.nan,inplace=True)
df['Price']=df['Price'].apply(pd.to_numeric,errors='ignore')
df['Price'].fillna(df['Price'].mean(),inplace=True)
df['Population'].fillna(df['Population'].mean(),inplace=True)'''
# Out:
# "df['Price'].replace('?',np.nan,inplace=True)\ndf['Price']=df['Price'].apply(pd.to_numeric,errors='ignore')\ndf['Price'].fillna(df['Price'].mean(),inplace=True)\ndf['Population'].fillna(df['Population'].mean(),inplace=True)"

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df1 = df[~((df< (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df1
'''
df = df[(df[i] >= Q1-1.5*IQR) & (df[i] <= Q3 + 1.5*IQR)]
'''
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Q1 = df.quantile(0.25)
#       2 Q3 = df.quantile(0.75)
#       3 IQR = Q3 - Q1
#
# File c:\Users\kesav\anaconda3\Lib\site-packages\pandas\core\frame.py:10882, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   10875 axis = self._get_axis_number(axis)
#   10877 if not is_list_like(q):
#   10878     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   10879     # error: List item 0 has incompatible type "Union[float, Union[Union[
#   10880     # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881     # expected "float"
# > 10882     res_df = self.quantile(  # type: ignore[call-overload]
#   10883         [q],
#   10884         axis=axis,
#   10885         numeric_only=numeric_only,
#   10886         interpolation=interpolation,
# ...

# %%
# Assume the price is in cents and you want to convert to dollars
df['Price'] = df['Price'] / 100  # Convert cents to dollars if that's the case

# Format the 'Price' column to a more readable format, like rounding to two decimal places
df['Price'] = df['Price'].round(2)
df
# Out:
#            Income  House age  Number of rooms  Number of bedrooms  \
# 0     79545.45857   5.682861         7.009188                4.09
# 1     79248.64245   6.002900         6.730821                3.09
# 2     61287.06718   5.865890         8.512727                5.13
# 3     63345.24005   7.188236         5.586729                3.26
# 4     59982.19723   5.040555         7.839388                4.23
# ...           ...        ...              ...                 ...
# 4995  60567.94414   7.830362         6.137356                3.46
# 4996  78491.27543   6.999135         6.576763                4.02
# 4997  63390.68689   7.250591         4.805081                2.13
# 4998  68001.33124   5.534388         7.130144                5.44
# 4999  65510.58180   5.992305         6.792336                4.07
#
#        Population     Price  Address
# 0     23086.80050  10590.34      962
# 1     40173.07217  15058.91      863
# 2     36882.15940  10589.88     4069
# ...

# %%
x=df1.drop('Price',axis=1)
y=df1['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
scaler=StandardScaler()
scaler.fit(x_train,y_train)
# Out:
# StandardScaler()

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.score(x_train,y_train)*100)
print(model.score(x_test,y_test)*100)
# Out:
# 91.22184801380308
# 90.75462270744204

# %%
savedfile=open('housingmodel.pklz','wb')
pickle.dump(model,savedfile)

# %%
readfile=open('housingmodel.pklz','rb')
newmodel=pickle.load(readfile)
newmodel.score(x_test,y_test)
# Out:
# 0.9081178667870534
